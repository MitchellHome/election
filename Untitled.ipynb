# %%
import pandas as pd

# %%
df = pd.read_csv('2015ProvincialElectionResults.csv')

# %%
df
# Out:
#     ED                             ED Name  Number\nof Polls  AFP    LIB  \
# 0    1       DUNVEGAN-CENTRAL PEACE-NOTLEY                58    0      0
# 1    2                   LESSER SLAVE LAKE                65    0      0
# 2    3                      CALGARY-ACADIA                72    0    765
# 3    4                         CALGARY-BOW                75    0    682
# 4    5                     CALGARY-BUFFALO                78    0  3,282
# 5    6                       CALGARY-CROSS                79    0  1,194
# 6    7                      CALGARY-CURRIE                90    0  1,441
# 7    8                        CALGARY-EAST                97    0    806
# 8    9                       CALGARY-ELBOW                85    0    565
# 9   10                  CALGARY-FISH CREEK                73    0      0
# 10  11                   CALGARY-FOOTHILLS                80    0  1,271
# 11  12                        CALGARY-FORT                80    0    476
# ...
